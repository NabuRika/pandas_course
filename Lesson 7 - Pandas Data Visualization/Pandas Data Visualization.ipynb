# %% [markdown]
# # Pandas Data Visualization

# %% [markdown]
# So far in this course, we have learned about many of the features that make Pandas one of the most popular data analysis and manipulation libraries. An essential part of any data analysis project is to perform a comprehensive exploratory analysis to help understand underlying patterns among the dataset variables.
#
# Although Pandas is not designed for comprehensive data visualization, it is capable of creating basic and practical plots.
#
# In this section, we will learn how to use Python Pandas to create two types of data visualizations:
#
# * Chart Visualization: Graphical representation of data using graphs such as histograms, pie charts, box plots, and so on.
# * Table Visualization: Graphical representation of data using HTML styling option within Pandas DataFrame objects.
# Pandas chart visualization can be achieved using the plot() method on Series and DataFrame objects. The function includes several parameters to identify the needed chart type as well as the targeted data columns. In this series of examples, we will use the plot() function to create some popular chart types.
#
# Time Series is one of the most commonly used charts to represent numerical values that change over a defined period of time. We can see this type of chart in visualizing financial market data like sales and price movement. In the Pandas library, the plot() method can be applied to a Series object with index values representing date values. Note that the line chart is the default type in the plot() method. Therefore, we do not need to change the type parameter. The following example demonstrates how a time series plot is used for visualization as shown in the example below:

# %%
import pandas as pd

# %%
# Import the dataset as a CSV file
df_air_passengers = pd.read_csv('https://raw.githubusercontent.com/jbrownlee/Datasets/master/airline-passengers.csv')

# Display DataFrame
df_air_passengers

# Set the Month values as the DataFrame index
df_air_passengers.set_index('Month', inplace = True)

# %%
# Plot the DataFrame
df_air_passengers.plot(figsize = (14,8));

# %% [markdown]
# Another commonly used visualization type to examine the relationship between two different numerical variables is a scatter plot. In the example below, we use the popular iris dataset to explore the relationship between petal length and width variables. We can use color grouping to add additional analytics dimensions. In this example, we are adding color groups based on each flower species.

# %%
# Import the dataset as a CSV file
df_iris = pd.read_csv('https://gist.githubusercontent.com/curran/a08a1080b88344b0c8a7/raw/0e7a9b0a5d22642a06d3d5b9bcbad9890c8ee534/iris.csv')

# Display DataFrame
df_iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# Apply a scatter plot to examine the relationship between variables
df_iris.plot(kind = 'scatter', x = 'petal_length', y = 'petal_width', figsize = (14,8));

# %%
# Map species to different color values
col = df_iris['species'].map({'setosa':'b', 
                              'versicolor':'r', 
                              'virginica':'y'})

# Apply a scatter plot to examine the relationship between variables
df_iris.plot(kind = 'scatter', x = 'petal_length', y = 'petal_width', c = col, figsize = (14,8));

# %% [markdown]
# Pandas table visualization can be achieved by adding styling instructions to DataFrame objects in order to be rendered as CSS styles. In the example below, we apply the horizontal bar style to the variable sepal_width while the data is sorted in descending order. We notice in the top row, the bar line covers the entire cell and its size countune to get smaller for the rest of the DataFrame.

# %%
# Add bar style to sepal_width variable
df_iris.sort_values(by = 'sepal_width', ascending = False).style.bar(subset=['sepal_width'], color = '#00AEE8')
# Out:
# <style type="text/css">
# #T_c7903_row0_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#00AEE8 100.0%, transparent 100.0%);
# }
# #T_c7903_row1_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#00AEE8 91.7%, transparent 91.7%);
# }
# #T_c7903_row2_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#00AEE8 87.5%, transparent 87.5%);
# }
# #T_c7903_row3_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#00AEE8 83.3%, transparent 83.3%);
# }
# #T_c7903_row4_col1, #T_c7903_row5_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#00AEE8 79.2%, transparent 79.2%);
# }
# #T_c7903_row6_col1, #T_c7903_row7_col1, #T_c7903_row8_col1, #T_c7903_row9_col1, #T_c7903_row10_col1, #T_c7903_row11_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#00AEE8 75.0%, transparent 75.0%);
# }
# #T_c7903_row12_col1, #T_c7903_row13_col1, #T_c7903_row14_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#00AEE8 70.8%, transparent 70.8%);
# }
# #T_c7903_row15_col1, #T_c7903_row16_col1, #T_c7903_row17_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#00AEE8 66.7%, transparent 66.7%);
# }
# #T_c7903_row18_col1, #T_c7903_row19_col1, #T_c7903_row20_col1, #T_c7903_row21_col1, #T_c7903_row22_col1, #T_c7903_row23_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#00AEE8 62.5%, transparent 62.5%);
# }
# #T_c7903_row24_col1, #T_c7903_row25_col1, #T_c7903_row26_col1, #T_c7903_row27_col1, #T_c7903_row28_col1, #T_c7903_row29_col1, #T_c7903_row30_col1, #T_c7903_row31_col1, #T_c7903_row32_col1, #T_c7903_row33_col1, #T_c7903_row34_col1, #T_c7903_row35_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#00AEE8 58.3%, transparent 58.3%);
# }
# #T_c7903_row36_col1, #T_c7903_row37_col1, #T_c7903_row38_col1, #T_c7903_row39_col1, #T_c7903_row40_col1, #T_c7903_row41_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#00AEE8 54.2%, transparent 54.2%);
# }
# #T_c7903_row42_col1, #T_c7903_row43_col1, #T_c7903_row44_col1, #T_c7903_row45_col1, #T_c7903_row46_col1, #T_c7903_row47_col1, #T_c7903_row48_col1, #T_c7903_row49_col1, #T_c7903_row50_col1, #T_c7903_row51_col1, #T_c7903_row52_col1, #T_c7903_row53_col1, #T_c7903_row54_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#00AEE8 50.0%, transparent 50.0%);
# }
# #T_c7903_row55_col1, #T_c7903_row56_col1, #T_c7903_row57_col1, #T_c7903_row58_col1, #T_c7903_row59_col1, #T_c7903_row60_col1, #T_c7903_row61_col1, #T_c7903_row62_col1, #T_c7903_row63_col1, #T_c7903_row64_col1, #T_c7903_row65_col1, #T_c7903_row66_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#00AEE8 45.8%, transparent 45.8%);
# }
# #T_c7903_row67_col1, #T_c7903_row68_col1, #T_c7903_row69_col1, #T_c7903_row70_col1, #T_c7903_row71_col1, #T_c7903_row72_col1, #T_c7903_row73_col1, #T_c7903_row74_col1, #T_c7903_row75_col1, #T_c7903_row76_col1, #T_c7903_row77_col1, #T_c7903_row78_col1, #T_c7903_row79_col1, #T_c7903_row80_col1, #T_c7903_row81_col1, #T_c7903_row82_col1, #T_c7903_row83_col1, #T_c7903_row84_col1, #T_c7903_row85_col1, #T_c7903_row86_col1, #T_c7903_row87_col1, #T_c7903_row88_col1, #T_c7903_row89_col1, #T_c7903_row90_col1, #T_c7903_row91_col1, #T_c7903_row92_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#00AEE8 41.7%, transparent 41.7%);
# }
# #T_c7903_row93_col1, #T_c7903_row94_col1, #T_c7903_row95_col1, #T_c7903_row96_col1, #T_c7903_row97_col1, #T_c7903_row98_col1, #T_c7903_row99_col1, #T_c7903_row100_col1, #T_c7903_row101_col1, #T_c7903_row102_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#00AEE8 37.5%, transparent 37.5%);
# }
# #T_c7903_row103_col1, #T_c7903_row104_col1, #T_c7903_row105_col1, #T_c7903_row106_col1, #T_c7903_row107_col1, #T_c7903_row108_col1, #T_c7903_row109_col1, #T_c7903_row110_col1, #T_c7903_row111_col1, #T_c7903_row112_col1, #T_c7903_row113_col1, #T_c7903_row114_col1, #T_c7903_row115_col1, #T_c7903_row116_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#00AEE8 33.3%, transparent 33.3%);
# }
# #T_c7903_row117_col1, #T_c7903_row118_col1, #T_c7903_row119_col1, #T_c7903_row120_col1, #T_c7903_row121_col1, #T_c7903_row122_col1, #T_c7903_row123_col1, #T_c7903_row124_col1, #T_c7903_row125_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#00AEE8 29.2%, transparent 29.2%);
# }
# #T_c7903_row126_col1, #T_c7903_row127_col1, #T_c7903_row128_col1, #T_c7903_row129_col1, #T_c7903_row130_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#00AEE8 25.0%, transparent 25.0%);
# }
# #T_c7903_row131_col1, #T_c7903_row132_col1, #T_c7903_row133_col1, #T_c7903_row134_col1, #T_c7903_row135_col1, #T_c7903_row136_col1, #T_c7903_row137_col1, #T_c7903_row138_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#00AEE8 20.8%, transparent 20.8%);
# }
# #T_c7903_row139_col1, #T_c7903_row140_col1, #T_c7903_row141_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#00AEE8 16.7%, transparent 16.7%);
# }
# #T_c7903_row142_col1, #T_c7903_row143_col1, #T_c7903_row144_col1, #T_c7903_row145_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#00AEE8 12.5%, transparent 12.5%);
# }
# #T_c7903_row146_col1, #T_c7903_row147_col1, #T_c7903_row148_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#00AEE8 8.3%, transparent 8.3%);
# }
# #T_c7903_row149_col1 {
#   width: 10em;
#   height: 80%;
# }
# </style>
# <table id="T_c7903_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >sepal_length</th>
#       <th class="col_heading level0 col1" >sepal_width</th>
#       <th class="col_heading level0 col2" >petal_length</th>
#       <th class="col_heading level0 col3" >petal_width</th>
#       <th class="col_heading level0 col4" >species</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c7903_level0_row0" class="row_heading level0 row0" >15</th>
#       <td id="T_c7903_row0_col0" class="data row0 col0" >5.700000</td>
#       <td id="T_c7903_row0_col1" class="data row0 col1" >4.400000</td>
#       <td id="T_c7903_row0_col2" class="data row0 col2" >1.500000</td>
#       <td id="T_c7903_row0_col3" class="data row0 col3" >0.400000</td>
#       <td id="T_c7903_row0_col4" class="data row0 col4" >setosa</td>
#     </tr>
#     <tr>
#       <th id="T_c7903_level0_row1" class="row_heading level0 row1" >33</th>
#       <td id="T_c7903_row1_col0" class="data row1 col0" >5.500000</td>
#       <td id="T_c7903_row1_col1" class="data row1 col1" >4.200000</td>
#       <td id="T_c7903_row1_col2" class="data row1 col2" >1.400000</td>
#       <td id="T_c7903_row1_col3" class="data row1 col3" >0.200000</td>
#       <td id="T_c7903_row1_col4" class="data row1 col4" >setosa</td>
#     </tr>
#     <tr>
#       <th id="T_c7903_level0_row2" class="row_heading level0 row2" >32</th>
#       <td id="T_c7903_row2_col0" class="data row2 col0" >5.200000</td>
#       <td id="T_c7903_row2_col1" class="data row2 col1" >4.100000</td>
#       <td id="T_c7903_row2_col2" class="data row2 col2" >1.500000</td>
#       <td id="T_c7903_row2_col3" class="data row2 col3" >0.100000</td>
#       <td id="T_c7903_row2_col4" class="data row2 col4" >setosa</td>
#     </tr>
#     <tr>
#       <th id="T_c7903_level0_row3" class="row_heading level0 row3" >14</th>
#       <td id="T_c7903_row3_col0" class="data row3 col0" >5.800000</td>
#       <td id="T_c7903_row3_col1" class="data row3 col1" >4.000000</td>
#       <td id="T_c7903_row3_col2" class="data row3 col2" >1.200000</td>
#       <td id="T_c7903_row3_col3" class="data row3 col3" >0.200000</td>
#       <td id="T_c7903_row3_col4" class="data row3 col4" >setosa</td>
#     </tr>
#     <tr>
#       <th id="T_c7903_level0_row4" class="row_heading level0 row4" >16</th>
#       <td id="T_c7903_row4_col0" class="data row4 col0" >5.400000</td>
#       <td id="T_c7903_row4_col1" class="data row4 col1" >3.900000</td>
#       <td id="T_c7903_r
